# %%
import pandas as pd
import os

# %%
train_tsv_dir = "dataset/train/boxes_transcripts_labels"
val_tsv_dir = "dataset/val/boxes_transcripts"
val_ann_tsv_dir = "dataset/val_w_ann/boxes_transcripts_labels"

# %%
def load_and_parse_tsv_files(directory):
    all_data = []
    for file in os.listdir(directory):
        if file.endswith('.tsv'):
            file_path = os.path.join(directory, file)
            df = pd.read_csv(file_path, sep=',', header=None)
            # print(df)
            if df.shape[1] == 8:
                df.columns = ['start_index', 'end_index', 'x_tl', 'y_tl', 'x_br', 'y_br', 'transcript', 'label']
            elif df.shape[1] == 7:
                df.columns = ['start_index', 'end_index', 'x_tl', 'y_tl', 'x_br', 'y_br', 'transcript']
            all_data.append(df)
    return pd.concat(all_data, ignore_index=True)

# %%
train_df = load_and_parse_tsv_files(train_tsv_dir)
# val_df = load_and_parse_tsv_files(val_tsv_dir)

# %%
print(train_df[:5])
# Out:
#    start_index  end_index  x_tl  y_tl  x_br  y_br  transcript  label
# 0           33         33   215     4   227    21           a  OTHER
# 1           35         44   235     3   308    21  Employee's  OTHER
# 2           46         51   311     3   349    20      social  OTHER
# 3           53         60   352     3   401    20    security  OTHER
# 4           62         67   404     3   457    21      number  OTHER

# %%
import spacy
from spacy.training import Example
import pandas as pd

# %%
def remove_overlapping_entities(entities):
    """Remove overlapping entities from the list."""
    if not entities:
        return entities
    
    # Sort entities by start index
    entities = sorted(entities, key=lambda x: x[0])
    
    non_overlapping_entities = []
    last_end = -1
    
    for start, end, label in entities:
        if start > last_end:
            non_overlapping_entities.append((start, end, label))
            last_end = end
    
    return non_overlapping_entities

# %%
import pandas as pd
import os
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin

# %%
# def convert_to_spacy_format(df):
#     df['transcript'] = df['transcript'].astype(str)
    
#     texts = []
#     annotations = []
    
#     grouped = df.groupby('transcript')
    
#     for text, group in grouped:
#         text_entities = []
#         for _, row in group.iterrows():
#             if pd.notna(row['start_index']) and pd.notna(row['end_index']) and pd.notna(row['label']):
#                 text_entities.append((int(row['start_index']), int(row['end_index']), row['label']))
        
#         # Remove overlapping entities
#         text_entities = remove_overlapping_entities(text_entities)
        
#         if text_entities:
#             texts.append(text)
#             annotations.append({'entities': text_entities})
    
#     return list(zip(texts, annotations))
def convert_to_spacy_format(df):
    df['transcript'] = df['transcript'].astype(str)
    texts = df['transcript'].tolist()
    entities = []
    for _, row in df.iterrows():
        print(row['transcript'])
        entities.append({
            'entities': [
                (0, len(row['transcript'])-1, row['label'])
            ]
        })
    return list(zip(texts, entities))

# %%
# train_df = clean_dataframe(train_df)
spacy_train_data = convert_to_spacy_format(train_df)
# spacy_val_data = convert_to_spacy_format(val_df)

# %%
# Print a sample of spacy_train_data
for text, annotations in spacy_train_data:
    # Filter entities where the label is not 'OTHER'
    non_other_entities = [ent for ent in annotations['entities'] if ent[2] != 'OTHER']
    
    if non_other_entities:
        print(f"Text: {text}")
        print(f"Entities: {non_other_entities}")
        print("-" * 40)

# %%
nlp = spacy.load("en_core_web_sm")  # Create a new, blank model
# ner = nlp.add_pipe("ner")

# %%
import random

# %%
print(spacy_train_data[int(random.random()):2])

# %%
import json

# Define the path to your existing JSON file
json_file_path = "./spacy_train_data.json"
cleaned_json_file_path = "./cleaned_spacy_train_data.json"

# Read the JSON file with the incorrect encoding
with open(json_file_path, 'r', encoding='utf-8') as f:
    data = f.read()

# Replace unwanted characters
data = data.replace('Â', '')  # Remove the Â character

# Load the JSON data
data = json.loads(data)

# Write the cleaned JSON data back to a new file
with open(cleaned_json_file_path, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
import json

# Load the cleaned JSON file to verify
with open(cleaned_json_file_path, 'r', encoding='utf-8') as f:
    cleaned_data = json.load(f)

# print(cleaned_data)  # Print to verify

# %%
db = DocBin() # create a DocBin object
# print(spacy_train_data[:2])
for text, annot in tqdm(cleaned_data): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    # print(type(doc))
    for start, end, label in annot["entities"]: # add character indexes
        # print(start,end,label,doc)
        # print(doc)
        span = doc.char_span(start,end,label=label,alignment_mode='expand')
        if span is None:
            print("Skipping entity")
        else:
            print('made it:',start,end,text,label)
            ents.append(span)
    doc.ents = ents # label the text with the ents
    db.add(doc)
# os.chdir(r'XXXX\XXXXX')
db.to_disk("train.spacy")

# %%
all_labels = set()
for _, annotations in spacy_train_data:
    for start, end, label in annotations['entities']:
        all_labels.add(label)
for label in all_labels:
    ner.add_label(label)

# %%
import random

# %%
print(len(spacy_train_data))
# Out:
# 20183

# %%
from spacy.training import Example

def train_spacy_model(nlp, train_data, batch_size=1000, n_epochs=50):
    """Train SpaCy model with batch processing."""
    optimizer = nlp.begin_training()

    for epoch in range(n_epochs):
        losses = {}
        # Shuffle the training data at the start of each epoch
        random.shuffle(train_data)
        
        # Process the data in batches
        for i in range(0, len(train_data), batch_size):
            batch = train_data[i:i+batch_size]
            examples = [Example.from_dict(nlp.make_doc(text), annotations) for text, annotations in batch]
            # Update the model with the current batch
            nlp.update(examples, drop=0.5, losses=losses)

        # Print losses for the current epoch
        print(f"Epoch {epoch}, Losses: {losses}")

# Assuming you have already defined `spacy_train_data`
train_spacy_model(nlp, spacy_train_data, batch_size=1000, n_epochs=3)

# %%
print(len(train_df))

# %%
nlp.to_disk("Runs/SCAPY3")

# %%
import spacy

# %%
model1 = spacy.load("output/model-best")

# %%
import os
import pandas as pd
import spacy

def add_predictions_to_tsv_single(model, input_file, output_file):
    # Load the TSV file into a DataFrame
    df = pd.read_csv(input_file, sep=',', header=None)
    df.columns = ['start_index', 'end_index', 'x_tl', 'y_tl', 'x_br', 'y_b', 'transcript']
    # Initialize a list to store predicted labels
    predicted_labels = []
    # Iterate through each transcript and predict labels
    for transcript in df['transcript']:
        if isinstance(transcript, str) and transcript.strip():
            # print(transcript)
            doc = model(transcript)  # Use the loaded model to predict entities
            if doc.ents:
                # Get the label of the first predicted entity (if any) for simplicity
                predicted_label = doc.ents[0].label_
            else:
                predicted_label = "OTHER"  # Fallback to "OTHER" if no entity is predicted
        else:
            predicted_label = "OTHER"  # Handle empty or invalid transcripts

        predicted_labels.append(predicted_label)
    
    # Add the predicted labels as a new column to the DataFrame
    df['predicted_label'] = predicted_labels
    
    # Save the updated DataFrame to the specified output TSV file
    df.to_csv(output_file, sep='\t', index=False, header=False)
    print(f"Updated file with predictions saved to {output_file}")

# Example usage
add_predictions_to_tsv_single(model1, "dataset/val/boxes_transcripts/7ca4a06b-83af-43cb-b737-3b14af27c894_document-1_page-1.tsv", "predictions.tsv")
# Out:
# Updated file with predictions saved to predictions.tsv

# %%
def add_predictions_to_tsv(model, tsv_file):
    for file_name in os.listdir(tsv_file):
        if file_name.endswith('.tsv'):
            file_path = os.path.join(tsv_file, file_name)
            df = pd.read_csv(file_path, sep=',', header=None)
            df.columns = ['start_index', 'end_index', 'x_tl', 'y_tl', 'x_br', 'y_b', 'transcript']
            predicted_labels = []
            for transcript in df['transcript']:
                if isinstance(transcript, str) and transcript.strip():
                    doc = model(transcript)  # Use the loaded model to predict entities
                    print(doc.ents)
                    if doc.ents:
                        # Get the label of the first predicted entity (if any) for simplicity
                        predicted_label = doc.ents[0].label_
                    else:
                        predicted_label = "OTHER"  # Fallback to "OTHER" if no entity is predicted
                else:
                    predicted_label = "OTHER"  # Handle empty or invalid transcripts

                predicted_labels.append(predicted_label)
            
            # Add the predicted labels as a new column to the DataFrame
            df['predicted_label'] = predicted_labels
            
            # Save the updated DataFrame to the same TSV file
            df.to_csv(file_path, sep=',', index=False, header=False)
            print(f"Updated {file_name} with predictions.")

add_predictions_to_tsv(model1, "dataset/val/boxes_transcripts")
# Out:
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (fe,)
# ()
# (file,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (634-61-7592,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Use,)
# (at,)
# (www.irs,)
# (govefile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (80-3888506,)
# (180450,)
# ()
# (56,)
# (30700,)
# ()
# (05,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (205649,)
# (34,)
# (15732,)
# ()
# (17,)
# (Arnold,)
# (Wood,)
# (and,)
# (Rivera,)
# (LLC,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (250,)
# (Martinez,)
# (Causeway,)
# (Suite,)
# (141,)
# (223895,)
# ()
# (04,)
# (6492,)
# ()
# (96,)
# (Kelseyfort,)
# (AK,)
# (91543-2875,)
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (205649,)
# (34,)
# (223895,)
# (04,)
# ()
# (Control,)
# (number,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (170,)
# (776585,)
# (2a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (175,)
# ()
# (8071,)
# (Lisa,)
# (Norris,)
# (13,)
# (Statutory,)
# (plan,)
# (Third-party,)
# (Retirement,)
# (sick,)
# (12b,)
# (employee,)
# (pay,)
# (7185,)
# (Ashley,)
# (Course,)
# (Suite,)
# (125,)
# ()
# ()
# (925,)
# (Other,)
# (12c,)
# (Vegamouth,)
# (DC,)
# (87111-2388,)
# (926,)
# (12d,)
# (FF,)
# (740,)
# ()
# (15,)
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (3764,)
# ()
# (41,)
# (233578,)
# (.53,)
# (33450,)
# ()
# (01,)
# (Fuller,)
# (Well,)
# (VT,)
# (517-95-205,)
# (89895,)
# ()
# (42,)
# (997-63-305,)
# (97088,)
# ()
# (47,)
# (3293,)
# (02,)
# (175857,)
# (82,)
# (21299,)
# ()
# (95,)
# (Jonathan,)
# (Mills,)
# (TX,)
# (Wage,)
# (and,)
# (Tax,)
# (2018,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# Updated 033ae477-99aa-4047-953d-4a951fc5a498_document-3_page-1.tsv with predictions.
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (Re,)
# ()
# (file,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (806-88-5109,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Use,)
# (at,)
# (www.irs.gov/efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (37-1222985,)
# (96644,)
# ()
# (87,)
# (24032,)
# ()
# (14,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Gillespie-Baldwin,)
# (and,)
# (Sons,)
# (86363.17,)
# (6606,)
# (78,)
# (046,)
# (Rodney,)
# (Inlet,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (98243.28,)
# (2849,)
# ()
# (06,)
# (Port,)
# (Crystal,)
# (WV,)
# (11997-2462,)
# ()
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (86363,)
# (17,)
# (98243.28,)
# ()
# (Control,)
# (number,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (9349624,)
# (187,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Brooke,)
# (Hutchinson,)
# (134,)
# ()
# (5985,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# (4964,)
# (Allen,)
# (Port,)
# (Apt,)
# (538,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# (922,)
# (Maryshire,)
# (HI,)
# (48965-6224,)
# (14,)
# (Other,)
# (120,)
# (DD,)
# (954,)
# (12d,)
# ()
# (125,)
# (15,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (NV,)
# (406-66-843,)
# (45969.5,)
# (4475,)
# ()
# (64,)
# (76331,)
# ()
# (18,)
# (18990,)
# ()
# (41,)
# (Justin,)
# (Walks,)
# (TX,)
# (769-47-436,)
# (45524,)
# ()
# (02,)
# (5295,)
# (03,)
# (71576.17,)
# (15695,)
# ()
# (21,)
# (Erica,)
# (Fall,)
# (Wage,)
# (and,)
# (Tax,)
# (2018,)
# (Department,)
# (of,)
# (the,)
# (Treasury-Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# Updated 033ae477-99aa-4047-953d-4a951fc5a498_document-4_page-1.tsv with predictions.
# (12a,)
# ()
# (Federal,)
# (income,)
# (21351,)
# (tax,)
# (withheld,)
# ()
# (82,)
# (Wages,)
# (146035.36,)
# (tips,)
# (other,)
# (comp,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (12677,)
# ()
# (83,)
# ()
# (Social,)
# (165723.33,)
# (security,)
# (wages,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (1305,)
# ()
# (76,)
# ()
# (Medicare,)
# (148474,)
# (wages,)
# ()
# (62,)
# (and,)
# (tips,)
# (Employer,)
# (use,)
# (36,)
# (only,)
# (Dept,)
# (150,)
# (Corp,)
# ()
# ()
# (Control,)
# (number,)
# (5759626,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (Wilkins,)
# (Martin,)
# (and,)
# (ZIP,)
# (and,)
# (code,)
# (Cummings,)
# (Group,)
# (21897,)
# (Stephanie,)
# (Plaza,)
# (Port,)
# (Charles,)
# (AR,)
# (22010-5028,)
# (#02021,)
# (Batch,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# ()
# (Employer's,)
# (FED,)
# (ID,)
# (number,)
# (42-9087738,)
# ()
# (Allocated,)
# (tips,)
# (148474,)
# ()
# (62,)
# (Social,)
# (165723.33,)
# (security,)
# (tips,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (216,)
# (19,)
# (Verification,)
# (Code,)
# (12,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# ()
# (11,)
# (Nonqualified,)
# (6430,)
# (152,)
# (plans,)
# (12b,)
# (BE,)
# (512,)
# (160,)
# (14,)
# (Other,)
# (12c,)
# (822,)
# (12d,)
# (13,)
# (Stat,)
# (emp,)
# (Ret,)
# (Plan,)
# (3rd,)
# (party,)
# ()
# (sick,)
# (pay,)
# ()
# (elf,)
# (Employees,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Tyler,)
# (Terry,)
# (61061,)
# (Stevenson,)
# (Light,)
# (31166-9800,)
# (Marissaborough,)
# (AL,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# (77589.52,)
# (15,)
# (State,)
# (NV,)
# (25-90-923,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (132060,)
# (etc,)
# (.7,)
# (17,)
# (State,)
# (5739.25,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (Devin,)
# (Street,)
# (19,)
# (Local,)
# (26475,)
# (income,)
# ()
# (02,)
# (tax,)
# (Copy,)
# (Filing,)
# (Federal,)
# (Wage,)
# (and,)
# (Tax,)
# (2018,)
# (Statement,)
# (W-2,)
# (OMB,)
# (No,)
# (1545-0008,)
# (Copy,)
# ()
# (to,)
# (be,)
# (filed,)
# (with,)
# (employee's,)
# (Federal,)
# (Income,)
# (Tax,)
# (Return,)
# Updated 03ca8d34-d060-49ee-b6cb-125e82305045_document-4_page-1.tsv with predictions.
# (Wages,)
# (tips,)
# (other,)
# (comp,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (217889.17,)
# (72621.77,)
# ()
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (153323.57,)
# (11729,)
# (25,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (262726,)
# (78,)
# (7619,)
# (08,)
# ()
# (Control,)
# (number,)
# (Dept,)
# (Corp.,)
# (Employer,)
# (use,)
# (36,)
# (only,)
# (3219657,)
# (150,)
# ()
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Patrick,)
# (PLC,)
# (Ltd,)
# (60575,)
# (Marilyn,)
# (Vista,)
# (North,)
# (Nicolestad,)
# (DE,)
# (93139-3274,)
# (Batch,)
# (#02021,)
# ()
# (Employer's,)
# (FED,)
# (ID,)
# (number,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# (85-2358997,)
# ()
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (153323.57,)
# (262726,)
# (78,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (292,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (103,)
# (14,)
# (Other,)
# (HH,)
# ()
# (5601,)
# (12b,)
# ()
# (145,)
# (12c,)
# (491,)
# (12d,)
# ()
# (403,)
# (13,)
# (Stat,)
# (emp,)
# (Ret,)
# (Plan,)
# (3rd,)
# (party,)
# (sick,)
# (pay,)
# (elf,)
# (Employees,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (Angela,)
# (Shepard,)
# (403,)
# (Nancy,)
# (Parks,)
# (Port,)
# (Roy,)
# (DE,)
# (30674-4338,)
# (State,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (OH,)
# (20-86-602,)
# (110522,)
# (etc,)
# ()
# (52,)
# (17,)
# (State,)
# (10729.06,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (238264,)
# (79,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (37910.51,)
# (Hunter,)
# (Junction,)
# (Federal,)
# (Filing,)
# (Copy,)
# (Wage,)
# (and,)
# (Tax,)
# (W-2,)
# (Statement,)
# (2018,)
# (Copy,)
# ()
# (to,)
# (be,)
# (filed,)
# (with,)
# (employee's,)
# (Federal,)
# (Income,)
# (Tax,)
# (Return,)
# (OMB,)
# (No,)
# (1545-0008,)
# Updated 03ca8d34-d060-49ee-b6cb-125e82305045_document-5_page-1.tsv with predictions.
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (RSe,)
# ()
# (file,)
# (137-86-9922,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (US,)
# (at,)
# (www.irs.gov/efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (80-1125366,)
# (70210,)
# (.42,)
# (25473,)
# ()
# (55,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Jefferson-Rocha,)
# (LLC,)
# (62567,)
# ()
# (06,)
# (4786,)
# (38,)
# (43147,)
# (Amy,)
# (Plain,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (Medicare,)
# (tax,)
# (withheld,)
# (55414,)
# ()
# (01,)
# (1607,)
# (01,)
# (Nancyland,)
# (IA,)
# (95502-7995,)
# (Social,)
# (security,)
# (tips,)
# (Allocated,)
# (tips,)
# (62567,)
# (06,)
# (55414,)
# ()
# (01,)
# ()
# (Control,)
# (number,)
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (183,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (144,)
# (4146,)
# (Sara,)
# (Scott,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12,)
# (employe,)
# (plan,)
# (sick,)
# (pay,)
# (8642,)
# (Robert,)
# (Branch,)
# (Suite,)
# (410,)
# (601,)
# (North,)
# (Christophershire,)
# (RI,)
# (28233-48,)
# (14,)
# (Other,)
# (12,)
# (394,)
# ()
# (997,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (15,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# ()
# (etc,)
# ()
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (WI,)
# (353-27-793,)
# (38332,)
# ()
# (56,)
# (1990.23,)
# (84667,)
# (47,)
# (13340,)
# ()
# (97,)
# (Jennifer,)
# (Mission,)
# (CA,)
# (789-50-285,)
# (36071,)
# ()
# (72,)
# (2172,)
# ()
# (85,)
# (50566,)
# (14,)
# (9516.93,)
# (Michael,)
# (Forks,)
# (Wage,)
# (and,)
# (Tax,)
# (2018,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# Updated 053f994b-599a-4d25-a72f-4ee9f88b4136_document-4_page-1.tsv with predictions.
# (compensation,)
# (Medicare,)
# (3581403,)
# (46652,)
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (824-49-5441,)
# (Safe,)
# (Accurate,)
# (30-3748192,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Use,)
# (we,)
# ()
# (file,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Wages,)
# (tips,)
# (other,)
# ()
# ()
# (at,)
# (on,)
# ()
# (www.irs.gov/efile,)
# (West,)
# (PLC,)
# (LLC,)
# (88329.53,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (Social,)
# (security,)
# (wages,)
# (9615,)
# ()
# (3612,)
# (Daniel,)
# (Avenue,)
# (110333,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Amandafurt,)
# (MN,)
# (97126-7718,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (8440,)
# ()
# (52,)
# (112840,)
# ()
# ()
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# ()
# (Control,)
# (number,)
# (Social,)
# (security,)
# (tips,)
# (3272.37,)
# (3581403,)
# (110333,)
# ()
# ()
# (Allocated,)
# (tips,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (112840,)
# ()
# (46,)
# (Last,)
# (name,)
# (Dependent,)
# (care,)
# (benefits,)
# (Mrs,)
# ()
# (Jennifer,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (179,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (568,)
# (Amber,)
# (Station,)
# (Apt,)
# (388,)
# (137,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# ()
# (6642,)
# (Gardnerbury,)
# (CA,)
# (39105-0186,)
# (employee,)
# (12,)
# ()
# ()
# (14,)
# (Other,)
# ()
# (502,)
# (12,)
# (486,)
# (15,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (12d,)
# (MA,)
# (556-15-723,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# ()
# (985,)
# (41803,)
# ()
# (48,)
# (3772,)
# (.56,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# ()
# (Local,)
# (income,)
# (tax,)
# (RI,)
# (621-39-697,)
# (102743,)
# (.56,)
# (20,)
# (Locality,)
# (name,)
# (46,)
# ()
# (52,)
# ()
# (01,)
# (10733,)
# ()
# (28,)
# (Wage,)
# (and,)
# (Tax,)
# (4656,)
# ()
# (66,)
# (65174,)
# ()
# (81,)
# (Peterson,)
# (Parks,)
# (Form,)
# (W-2,)
# (Statement,)
# (2019,)
# (17362,)
# ()
# (17,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (George,)
# (Revenue,)
# (Trail,)
# (Service,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Cut,)
# (here,)
# ("Keep,)
# (lower,)
# (portion,)
# (for,)
# (your,)
# (records,)
# (Employee's,)
# (social,)
# (security,)
# (number,)
# ()
# (Employer,)
# (identification,)
# (number,)
# (824-49-5441,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (If,)
# (you,)
# ()
# ()
# (30-3748192,)
# (OMB,)
# (No,)
# (1545-0008,)
# (required,)
# (to,)
# (file,)
# (tax,)
# (return,)
# (negligence,)
# (penalty,)
# (or,)
# (other,)
# (sanction,)
# (may,)
# (be,)
# (imposed,)
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (on,)
# (you,)
# (other,)
# (Wages,)
# (tips,)
# (if,)
# (this,)
# (compensation,)
# (income,)
# (is,)
# (taxable,)
# (and,)
# (you,)
# (fail,)
# (to,)
# (report,)
# (it,)
# (West,)
# (PLC,)
# (LLC,)
# (88329.53,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (Social,)
# (security,)
# (wages,)
# (9615,)
# ()
# ()
# (3612,)
# (Daniel,)
# (Avenue,)
# (110333,)
# ()
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Amandafurt,)
# (MN,)
# (97126-7718,)
# ()
# (are,)
# (wages,)
# (and,)
# (tips,)
# (8440,)
# ()
# (112840,)
# (.46,)
# (Medicare,)
# (tax,)
# (withheld,)
# (Control,)
# (number,)
# (Social,)
# (security,)
# (tips,)
# (3272,)
# (37,)
# ()
# (110333,)
# ()
# (Allocated,)
# (tips,)
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (112840,)
# (.46,)
# (Last,)
# (name,)
# (10,)
# (ndent,)
# (care,)
# (benefits,)
# (Mrs,)
# ()
# (Jennifer,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (179,)
# (for,)
# (box,)
# (12,)
# (12a,)
# (See,)
# (instructions,)
# (568,)
# (Amber,)
# (Station,)
# (Apt,)
# (388,)
# (137,)
# (13,)
# (Statutory,)
# (Third-party,)
# (|6642,)
# (Gardnerbury,)
# (CA,)
# (39105-0186,)
# ()
# (sick,)
# (pay,)
# (12b,)
# (Other,)
# ((see,)
# (enclosed,)
# (Notice,)
# ()
# (to,)
# (Employee,)
# ()
# (502,)
# (12,)
# ()
# (1486,)
# (15,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (12d,)
# (MA,)
# (556-15-723,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# ()
# (985,)
# (41803,)
# ()
# (48,)
# (3772,)
# ()
# (56,)
# (13,)
# (Local,)
# (wages,)
# (tics,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (RT,)
# (621-39-697,)
# (102743,)
# (.56,)
# (10733,)
# (.28,)
# (20,)
# (Locality,)
# (name,)
# (Wage,)
# (and,)
# (Tax,)
# (46652,)
# ()
# (01,)
# (4656,)
# (66,)
# (65174,)
# ()
# (81,)
# (Peterson,)
# (Parks,)
# (Form,)
# (W-2,)
# (Statement,)
# (2019,)
# (17362,)
# ()
# (17,)
# (Copy,)
# ()
# (For,)
# (EMPLOYEE'S,)
# (RECORDS,)
# ((See,)
# (Notice,)
# (to,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (George,)
# (Revenue,)
# (Trail,)
# (Service,)
# (Employee,)
# (the,)
# (back,)
# (of,)
# (Copy,)
# (B.),)
# (Safe,)
# (accurate,)
# (FAST,)
# (Use,)
# (file,)
# Updated 05cf86f4-299a-4b93-8ba3-b59c88499280_document-1_page-1.tsv with predictions.
# (information,)
# (being,)
# (This,)
# (12a,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (Safe,)
# (Accurate,)
# (se,)
# ()
# (file,)
# (at,)
# (www.irs.gov/efile,)
# (FAST,)
# (Use,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (OMB,)
# (No,)
# (1545-0008,)
# (8016,)
# (61,)
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (837-50-9366,)
# (163672,)
# ()
# (65,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Social,)
# (security,)
# (wages,)
# (12187,)
# (.22,)
# (159310.11,)
# (Medicare,)
# (tax,)
# (withheld,)
# ()
# (Employer,)
# (68-4822665,)
# (identification,)
# (number,)
# ((EIN,)
# (4860.87,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (167616,)
# ()
# (12,)
# (Allocated,)
# (tips,)
# (167616.12,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (Welch,)
# (Inc,)
# (and,)
# (Sons,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (tips,)
# (467,)
# (Kelly,)
# (Curve,)
# (09829-7504,)
# (159310.11,)
# (10,)
# (Dependent,)
# (care,)
# (146,)
# (benefits,)
# (West,)
# (Victoria,)
# (AL,)
# ()
# (12,)
# ()
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (AA,)
# (2793,)
# ()
# (Control,)
# (number,)
# (21,)
# (Third-party,)
# (12,)
# (6090573,)
# (Last,)
# (name,)
# (13,)
# (Statutory,)
# (Retirement,)
# (sick,)
# (pay,)
# (DID,)
# (515,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (employee,)
# (12,)
# (Dawn,)
# (Whitaker,)
# (14,)
# (Other,)
# (667,)
# (07256-64,)
# ()
# (48103,)
# (Karla,)
# (Row,)
# (IN,)
# ()
# (908,)
# (Lake,)
# (Jessicaview,)
# (20,)
# (Locality,)
# (name,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (Thomas,)
# (Valleys,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (24724,)
# ()
# (62,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (119247,)
# ()
# (44,)
# (Samuel,)
# (Roads,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (2875,)
# ()
# (97,)
# (25113,)
# ()
# (49,)
# ()
# (15,)
# (Employee's,)
# (State,)
# (address,)
# (Employer's,)
# (and,)
# (state,)
# (ZIP,)
# (ID,)
# (code,)
# (number,)
# (74986,)
# ()
# (86,)
# (128075,)
# ()
# (84,)
# (161-40-863,)
# (3016,)
# (99,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (DC,)
# (83109,)
# ()
# (709-62-383,)
# (2019,)
# (FL,)
# (Wage,)
# (and,)
# (Tax,)
# (Statement,)
# (Form,)
# (W-2,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (is,)
# (for,)
# ()
# (on,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Cut,)
# (here,)
# (Keep,)
# (lower,)
# (portion,)
# ()
# (or,)
# (your,)
# (records,)
# (This,)
# (information,)
# (is,)
# (be,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (If,)
# (you,)
# (are,)
# (required,)
# (to,)
# (file,)
# ()
# (tax,)
# (return,)
# (negligence,)
# (Federal,)
# (penalty,)
# (income,)
# (other,)
# (sanction,)
# (may,)
# ()
# ()
# (imposed,)
# (OMB,)
# (No,)
# (1545-0008,)
# (on,)
# (you,)
# (if,)
# (this,)
# (income,)
# (taxable,)
# (and,)
# (you,)
# (fail,)
# (18016.61,)
# (to,)
# (report,)
# (it,)
# (tax,)
# (withheld,)
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (837-50-9366,)
# (163672,)
# ()
# (65,)
# (Social,)
# (security,)
# (wages,)
# (12187.22,)
# (159310.11,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (4860,)
# ()
# (87,)
# (Employer,)
# (identification,)
# (number,)
# (68-4822665,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (167616,)
# ()
# (12,)
# ()
# (Allocated,)
# (tips,)
# (167616,)
# (12,)
# (Welch,)
# (Inc,)
# (and,)
# (Sons,)
# (Social,)
# (security,)
# (tips,)
# (467,)
# (Kelly,)
# (Curve,)
# (09829-7504,)
# (159310,)
# (11,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (146,)
# (West,)
# (Victoria,)
# (AL,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (AA,)
# (2793,)
# ()
# (Control,)
# (number,)
# (211,)
# (Third-party,)
# (12b,)
# (6090573,)
# (Last,)
# (name,)
# (13,)
# (Statutory,)
# (Retirement,)
# (sick,)
# (pay,)
# (DD,)
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (employee,)
# (plan,)
# ()
# ()
# (Whitaker,)
# (14,)
# (Other,)
# ((see,)
# (enclosed,)
# (Notice,)
# (to,)
# (Employee,)
# ()
# (12c,)
# (667,)
# (Dawn,)
# (12d,)
# (48103,)
# (Karla,)
# (Row,)
# (07256-64,)
# ()
# (908,)
# (Lake,)
# (Jessicaview,)
# (IN,)
# (20,)
# (Locality,)
# (name,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (Thomas,)
# (Valleys,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (24724,)
# ()
# (62,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (119247,)
# ()
# (44,)
# (Samuel,)
# (Roads,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (2875.97,)
# (25113,)
# ()
# (49,)
# (15,)
# (Employee's,)
# (address,)
# (and,)
# (State,)
# (Employer's,)
# (state,)
# (ZIP,)
# (ID,)
# (code,)
# (number,)
# (74986,)
# ()
# (86,)
# (128075,)
# ()
# (84,)
# (161-40-863,)
# (3016,)
# ()
# (99,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (DC,)
# (83109.1,)
# (Safe,)
# (accurate,)
# (Re,)
# ()
# (file,)
# (709-62-383,)
# (2019,)
# (FAST,)
# (Use,)
# (FL,)
# (Wage,)
# (and,)
# (Tax,)
# (Statement,)
# (Form,)
# (W-2,)
# (Copy,)
# ()
# (For,)
# (EMPLOYEE'S,)
# (RECORDS,)
# ((See,)
# (Notice,)
# (to,)
# (mployee,)
# (the,)
# (back,)
# (of,)
# (Copy,)
# (B.),)
# Updated 05cf86f4-299a-4b93-8ba3-b59c88499280_document-4_page-1.tsv with predictions.
# (sanction,)
# (Medicare,)
# (Use,)
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (467-08-8770,)
# (Safe,)
# (Accurate,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (se,)
# ()
# ()
# (file,)
# (at,)
# (www.irs.gov/efile,)
# (91-4559008,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# ()
# (Employer's,)
# (name,)
# (s,)
# (and,)
# (ZIP,)
# (code,)
# (141025.22,)
# (28756,)
# (.86,)
# (Hunt,)
# (Knox,)
# (and,)
# (Morgan,)
# (Inc,)
# (ocial,)
# (security,)
# (tax,)
# (withheld,)
# (698,)
# (Perry,)
# (Trace,)
# (110191,)
# (.96,)
# (8429,)
# ()
# (68,)
# (Medicare,)
# (yes,)
# (and,)
# (tips,)
# (Medicare,)
# (tax,)
# (withheld,)
# (North,)
# (Johnfort,)
# (KS,)
# (81268-3528,)
# (155756.27,)
# (Social,)
# (security,)
# (tips,)
# (4516.93,)
# ()
# (Control,)
# (number,)
# (110191,)
# ()
# (96,)
# (Allocated,)
# (tips,)
# (155756,)
# (27,)
# (2730634,)
# (Dependent,)
# (care,)
# (benefits,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (299,)
# (Sulf,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Joseph,)
# (Butler,)
# (226,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12,)
# ()
# (5190,)
# (8288,)
# (Campbell,)
# (Brooks,)
# (Apt,)
# (436,)
# (sick,)
# (gay,)
# (West,)
# (Williamport,)
# (SD,)
# (00755-5542,)
# (Other,)
# ()
# (968,)
# (12,)
# ()
# ()
# (437,)
# (12d,)
# ()
# (15,)
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (State,)
# (Employer's,)
# ()
# (624,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (IA,)
# (131-76-163,)
# (70963,)
# (38,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (3365,)
# ()
# (38,)
# (99817.0,)
# (20,)
# (Locality,)
# (name,)
# (15027,)
# ()
# (88,)
# (Miller,)
# (Mission,)
# (CA,)
# (825-47-958,)
# (63940,)
# (29,)
# (2516.51,)
# (Wage,)
# (and,)
# (Tax,)
# (160235,)
# ()
# (68,)
# (21174,)
# ()
# (04,)
# (2019,)
# (Mayo,)
# (Valleys,)
# (Form,)
# (W-2,)
# (Statement,)
# (Department,)
# (of,)
# (the,)
# (Treasury-.Internal,)
# (Revenue,)
# (Service,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Cut,)
# (here,)
# (Keep,)
# (lower,)
# (portion,)
# (for,)
# (your,)
# (records,)
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (467-08-8770,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (If,)
# (you,)
# ()
# ()
# (Employer,)
# (iden,)
# (OMB,)
# (No,)
# (1545-0008,)
# (required,)
# (to,)
# (file,)
# ()
# (tax,)
# (return,)
# (negligence,)
# (penalty,)
# (or,)
# (other,)
# ()
# (on,)
# (may,)
# (be,)
# (imposed,)
# (on,)
# (you,)
# (other,)
# (if,)
# (this,)
# (compensation,)
# (income,)
# (is,)
# (taxable,)
# (and,)
# (you,)
# (fail,)
# (to,)
# (report,)
# (it,)
# (91-4559008,)
# (Wages,)
# (tips,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (141025.22,)
# (28756,)
# ()
# (86,)
# (Hunt,)
# (Knox,)
# (and,)
# (Morgan,)
# (Inc,)
# (Social,)
# (sec,)
# (arity,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (698,)
# (Perry,)
# (Trace,)
# (110191,)
# ()
# (96,)
# (8429,)
# ()
# (68,)
# (Medica,)
# (wages,)
# (and,)
# (tips,)
# ()
# (are,)
# (tax,)
# (withheld,)
# (North,)
# (Johnfort,)
# (KS,)
# (81268-3528,)
# (155756.27,)
# (Social,)
# (security,)
# (tips,)
# (4516,)
# (93,)
# ()
# (Control,)
# (nu,)
# (110191,)
# ()
# (96,)
# (Allocated,)
# (tips,)
# (155756.27,)
# (2730634,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (299,)
# (Sull,)
# (11,)
# (Nong,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Joseph,)
# (Butler,)
# (226,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# ()
# (5190,)
# (8288,)
# (Campbell,)
# (Brooks,)
# (Apt,)
# (436,)
# (sick,)
# (pay,)
# (968,)
# (West,)
# (Williamport,)
# (SD,)
# (00755-5542,)
# (Other,)
# ((see,)
# (enclosed,)
# (Notice,)
# (to,)
# (Employee,)
# (12c,)
# ()
# ()
# (437,)
# (12d,)
# ()
# (15,)
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# ()
# (624,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (TA,)
# (131-76-163,)
# (70963,)
# (38,)
# (3365,)
# ()
# (38,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (99817.0,)
# (15027,)
# ()
# (88,)
# (CA,)
# (825-47-958,)
# (Miller,)
# (Mission,)
# (63940,)
# (.29,)
# (2516,)
# (51,)
# (160235,)
# ()
# (68,)
# (Wage,)
# (and,)
# (Tax,)
# (21174,)
# (.04,)
# (Mayo,)
# (Valleys,)
# (Form,)
# (W-2,)
# (Statement,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury-.Internal,)
# (Revenue,)
# (Service,)
# (Copy,)
# ()
# (For,)
# (EMPLOYEE'S,)
# (RECORDS,)
# ((See,)
# (Notice,)
# (to,)
# (Safe,)
# (accurate,)
# (Employee,)
# (the,)
# (back,)
# (of,)
# (Copy,)
# (B.),)
# (FAST,)
# (Use,)
# (me,)
# ()
# (file,)
# Updated 05cf86f4-299a-4b93-8ba3-b59c88499280_document-8_page-1.tsv with predictions.
# ()
# (Wages,)
# (tips,)
# (other,)
# (comp,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (243726.91,)
# (70369.09,)
# ()
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (267545.68,)
# (20467.24,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (250657.51,)
# (7269.07,)
# ()
# (Control,)
# (number,)
# (Dept,)
# (Corp.,)
# (Employer,)
# (use,)
# (only,)
# (8253660,)
# (150,)
# ()
# (36,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Cox,)
# (Anderson,)
# (and,)
# (Sanchez,)
# (Group,)
# (469,)
# (Andrew,)
# (Highway,)
# (Apt,)
# (637,)
# (South,)
# (Darrell,)
# (MN,)
# (12183-2544,)
# (Batch,)
# (#02021,)
# ()
# (Employer's,)
# (FED,)
# (ID,)
# (number,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# (72-0239768,)
# ()
# ()
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (267545.68,)
# (250657.51,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# ()
# (258,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (109,)
# ()
# ()
# (3381,)
# (14,)
# (Other,)
# (12b,)
# ()
# ()
# (370,)
# (12c,)
# ()
# ()
# (342,)
# (12d,)
# ()
# ()
# (290,)
# (13,)
# (Stat,)
# (emp,)
# (Ret,)
# (Plan,)
# (3rd,)
# (party,)
# (sick,)
# (pay,)
# ()
# ()
# ()
# (e/,)
# (Employees,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Jennifer,)
# (Burch,)
# (34499,)
# (Mills,)
# (Unions,)
# (Apt,)
# (434,)
# (West,)
# (Karentown,)
# (IN,)
# (05129-4210,)
# (15,)
# (State,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (NC,)
# (758-62-786,)
# (121749.56,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (15856.16,)
# (190519.93,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# Updated 0b55f878-9dc7-478b-9bba-342056684452_document-1_page-1.tsv with predictions.
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (Rev,)
# (file,)
# (687-42-9884,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Us,)
# (at,)
# (www.irs.gov/efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (94-4138338,)
# (180558,)
# ()
# (05,)
# (42829,)
# (25,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Howell-Medina,)
# (Ltd,)
# (139843,)
# (75,)
# (10698,)
# ()
# (05,)
# (490,)
# (Parker,)
# (Bypass,)
# (Suite,)
# (313,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (171877,)
# (.83,)
# (4984,)
# ()
# (46,)
# (Knappburgh,)
# (MD,)
# (35300-1931,)
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (139843,)
# ()
# (75,)
# (171877.83,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (1,)
# (156,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (249,)
# (7498,)
# (Kim,)
# (Moore,)
# (12b,)
# (13,)
# (Statutory,)
# (Retirement,)
# (ird-part,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# (98194,)
# (King,)
# (Course,)
# (Suite,)
# (120,)
# (HH,)
# (518,)
# (North,)
# (Taylorland,)
# (MN,)
# (70203-8933,)
# (14,)
# (Other,)
# (12,)
# ()
# (640,)
# (120,)
# ()
# (891,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (15,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (OH,)
# (937-63-147,)
# (97631,)
# ()
# (03,)
# (5015,)
# (72,)
# (228423,)
# (38,)
# (29384,)
# (04,)
# (Thompson,)
# (Road,)
# (SD,)
# (554-60-329,)
# (95187,)
# ()
# (65,)
# (4241,)
# ()
# (71,)
# (182594,)
# ()
# (68,)
# (25948,)
# (03,)
# (Andres,)
# (Parks,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Cut,)
# (here,)
# (Keep,)
# (Tower,)
# (portion,)
# (for,)
# (your,)
# (records,)
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (If,)
# (you,)
# (are,)
# (required,)
# (687-42-9884,)
# (OMB,)
# (No,)
# (1545-0008,)
# (to,)
# (file,)
# ()
# (tax,)
# (return,)
# ()
# (negligence,)
# (penalty,)
# (or,)
# (other,)
# (sanction,)
# (may,)
# (be,)
# (imposed,)
# (on,)
# (you,)
# (if,)
# (this,)
# (income,)
# (is,)
# (taxable,)
# (and,)
# (you,)
# (fail,)
# (to,)
# (report,)
# (it,)
# ()
# (Employer,)
# (identification,)
# (number,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (94-4138338,)
# (180558,)
# ()
# (05,)
# (42829.25,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Howell-Medina,)
# (Ltd,)
# (139843,)
# (75,)
# (10698,)
# ()
# (05,)
# (490,)
# (Parker,)
# (Bypass,)
# (Suite,)
# (313,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (Medicare,)
# (tax,)
# (withheld,)
# (171877.83,)
# (4984,)
# ()
# (46,)
# (Knappburgh,)
# (MD,)
# (35300-1931,)
# (Social,)
# (security,)
# (tips,)
# (Allocated,)
# (tips,)
# (139843,)
# ()
# (75,)
# (171877.83,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (1552023,)
# (156,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (249,)
# ()
# (7498,)
# (Kim,)
# (Moore,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# (98194,)
# (King,)
# (Course,)
# (Suite,)
# (120,)
# (HH,)
# (518,)
# (North,)
# (Taylorland,)
# (MN,)
# (70203-8933,)
# (14,)
# (Other,)
# ((see,)
# (enclosed,)
# (Notice,)
# (to,)
# (Employee,)
# ()
# (12c,)
# ()
# (640,)
# (12,)
# ()
# ()
# (891,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (15,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (OH,)
# (937-63-147,)
# (97631,)
# (03,)
# (5015,)
# ()
# (72,)
# (228423,)
# (38,)
# (29384,)
# ()
# (04,)
# (Thompson,)
# (Road,)
# (SD,)
# (554-60-329,)
# (95187,)
# ()
# (65,)
# (1241,)
# ()
# (71,)
# (182594,)
# ()
# (68,)
# (25948,)
# ()
# (03,)
# (Andres,)
# (Parks,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Safe,)
# (accurate,)
# (uhse,)
# ()
# (file,)
# (Copy,)
# ()
# (For,)
# (EMPLOYEE'S,)
# (RECORDS,)
# ((See,)
# (Notice,)
# (to,)
# (FAST,)
# (Use,)
# (Employee,)
# (on,)
# (the,)
# (back,)
# (of,)
# (Copy,)
# (B.),)
# Updated 0d611bad-b2fe-4cf8-a634-cc5a1a79bf57_document-2_page-1.tsv with predictions.
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (Rev,)
# (file,)
# (149-21-8916,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Us,)
# (at,)
# (www.irs.gov/efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (37-5867736,)
# (63609,)
# ()
# (17365,)
# ()
# (94,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Jackson,)
# (PLC,)
# (PLC,)
# (68780,)
# ()
# (61,)
# (5261,)
# ()
# (72,)
# (2070,)
# (Martinez,)
# (Ridge,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (50062,)
# ()
# (03,)
# (1451,)
# ()
# ()
# (Davidtown,)
# (KY,)
# (03734-2195,)
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (68780,)
# ()
# (61,)
# (50062,)
# (03,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (48,)
# (177,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (157,)
# ()
# (8715,)
# (Tony,)
# (Ross,)
# (12b,)
# (13,)
# (Statutory,)
# (Retirement,)
# (ird-part,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# (345,)
# (Cody,)
# (Bypass,)
# (Apt,)
# (022,)
# ()
# (HH,)
# (727,)
# (Thompsonfurt,)
# (RI,)
# (72971-7767,)
# (14,)
# (Other,)
# (12,)
# ()
# (787,)
# (444,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (15,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (WY,)
# (908-98-200,)
# (32012,)
# ()
# (26,)
# (2007,)
# (.92,)
# (52928.93,)
# (7844,)
# (17,)
# (Tiffany,)
# (Burg,)
# (MI,)
# (109-03-959,)
# (33910,)
# ()
# (06,)
# (2590,)
# ()
# (48,)
# (75860,)
# ()
# (57,)
# (8725,)
# ()
# (74,)
# (Evans,)
# (Station,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Cut,)
# (here,)
# ()
# (Keep,)
# (Tower,)
# (portion,)
# (for,)
# (your,)
# (records,)
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (If,)
# (you,)
# (are,)
# (required,)
# (149-21-8916,)
# (OMB,)
# (No,)
# (1545-0008,)
# (to,)
# (file,)
# ()
# (tax,)
# (return,)
# ()
# (negligence,)
# (penalty,)
# (or,)
# (other,)
# (sanction,)
# (may,)
# (be,)
# (imposed,)
# (on,)
# (you,)
# (if,)
# (this,)
# (income,)
# (is,)
# (taxable,)
# (and,)
# (you,)
# (fail,)
# (to,)
# (report,)
# (it,)
# ()
# (Employer,)
# (identification,)
# (number,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (37-5867736,)
# (63609.3,)
# (17365,)
# ()
# (94,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Jackson,)
# (PLC,)
# (PLC,)
# (68780,)
# ()
# (61,)
# (5261,)
# ()
# (72,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (Medicare,)
# (tax,)
# (withheld,)
# (2070,)
# (Martinez,)
# (Ridge,)
# (50062,)
# ()
# (03,)
# (1451,)
# ()
# ()
# (Davidtown,)
# (KY,)
# (03734-2195,)
# (Social,)
# (security,)
# (tips,)
# (Allocated,)
# (tips,)
# (68780,)
# ()
# (61,)
# (50062,)
# ()
# (03,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (4895608,)
# (17,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (157,)
# ()
# (8715,)
# (Tony,)
# (Ross,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# (employee,)
# (lan,)
# (sick,)
# (pay,)
# (345,)
# (Cody,)
# (Bypass,)
# (Apt,)
# (022,)
# ()
# (HH,)
# (727,)
# (Thompsonfurt,)
# (RI,)
# (72971-7767,)
# (14,)
# (Other,)
# ((see,)
# (enclosed,)
# (Notice,)
# (to,)
# (Employee,)
# ()
# (12c,)
# (|787,)
# (12d,)
# (144,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (WY,)
# (908-98-200,)
# (32012,)
# ()
# (26,)
# (2007,)
# ()
# (92,)
# (52928.93,)
# (7844,)
# ()
# (17,)
# (Tiffany,)
# (Burg,)
# (MI,)
# (109-03-959,)
# (33910,)
# (.06,)
# (2590,)
# ()
# (48,)
# (75860,)
# (.57,)
# (8725,)
# ()
# (74,)
# (Evans,)
# (Station,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Safe,)
# (accurate,)
# (the,)
# ()
# (file,)
# (Copy,)
# ()
# (For,)
# (EMPLOYEE'S,)
# (RECORDS,)
# ((See,)
# (Notice,)
# (to,)
# (FAST,)
# (Use,)
# (Employee,)
# (on,)
# (the,)
# (back,)
# (of,)
# (Copy,)
# (B.),)
# Updated 0d611bad-b2fe-4cf8-a634-cc5a1a79bf57_document-5_page-1.tsv with predictions.
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (388-91-5728,)
# (Rev,)
# (file,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Us,)
# (at,)
# (www.irs.gov/efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (73-1929189,)
# (219960,)
# (.94,)
# (75109,)
# ()
# (88,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Campbell-Jones,)
# (LLC,)
# (156871,)
# (01,)
# (12000,)
# ()
# (63,)
# (4859,)
# (Jason,)
# (Springs,)
# (Suite,)
# (702,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (232090,)
# ()
# (32,)
# (6730,)
# ()
# (62,)
# (Hallland,)
# (DE,)
# (37834-7387,)
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (156871,)
# ()
# (01,)
# (232090,)
# ()
# (32,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (132,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (177,)
# (5967,)
# (Denise,)
# (Stout,)
# (13,)
# (Statutory,)
# (Retirement,)
# ()
# (hird-party,)
# (12,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# (66357,)
# (Tapia,)
# (Springs,)
# (Apt,)
# (943,)
# ()
# ()
# (448,)
# (Ashleymouth,)
# (PA,)
# (69126-5360,)
# (14,)
# (Other,)
# ()
# (690,)
# ()
# (547,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# ()
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (DC,)
# (113-26-326,)
# (118215,)
# (74,)
# (4792,)
# (.26,)
# (258168.58,)
# (37047,)
# ()
# (41,)
# (Carlos,)
# (Knoll,)
# (NH,)
# (869-73-936,)
# (100003,)
# (14,)
# (4458,)
# ()
# (96,)
# (254629,)
# (21,)
# (39470,)
# ()
# (95,)
# (Katherine,)
# (Loaf,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Cut,)
# (here,)
# ()
# (Keep,)
# (lower,)
# (portion,)
# (for,)
# (your,)
# (records,)
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (If,)
# (you,)
# (are,)
# (required,)
# (388-91-5728,)
# (OMB,)
# (No,)
# (1545-0008,)
# (to,)
# (file,)
# ()
# (tax,)
# (return,)
# ()
# (negligence,)
# (penalty,)
# (or,)
# (other,)
# (sanction,)
# (may,)
# (be,)
# (imposed,)
# (on,)
# (you,)
# (if,)
# (this,)
# (income,)
# (is,)
# (taxable,)
# (and,)
# (you,)
# (fail,)
# (to,)
# (report,)
# (it,)
# ()
# (Employer,)
# (identification,)
# (number,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (73-1929189,)
# (219960,)
# (.94,)
# (75109,)
# (88,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Campbell-Jones,)
# (LLC,)
# (156871,)
# ()
# (01,)
# (12000,)
# (.63,)
# (4859,)
# (Jason,)
# (Springs,)
# (Suite,)
# (702,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (Medicare,)
# (tax,)
# (withheld,)
# (232090,)
# ()
# (32,)
# (6730,)
# ()
# (62,)
# (Hallland,)
# (DE,)
# (37834-7387,)
# (Allocated,)
# (tips,)
# (Social,)
# (security,)
# (tips,)
# (156871,)
# ()
# (01,)
# (232090,)
# ()
# (32,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (679611,)
# (132,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (177,)
# (5967,)
# (Denise,)
# (Stout,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# (employee,)
# (lan,)
# (sick,)
# (pay,)
# (66357,)
# (Tapia,)
# (Springs,)
# (Apt,)
# (943,)
# ()
# ()
# ()
# (1448,)
# (Ashleymouth,)
# (PA,)
# (69126-5360,)
# (14,)
# (Other,)
# ((see,)
# (enclosed,)
# (Notice,)
# (to,)
# (Employee,)
# ()
# (12c,)
# (690,)
# (12d,)
# ()
# (547,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (DC,)
# (113-26-326,)
# (118215,)
# (74,)
# (4792,)
# ()
# (26,)
# (258168,)
# (.58,)
# (37047,)
# ()
# (41,)
# (Carlos,)
# (Knoll,)
# (NH,)
# (869-73-936,)
# (100003,)
# ()
# (14,)
# (4458,)
# ()
# (96,)
# (254629,)
# ()
# (21,)
# (39470,)
# ()
# (95,)
# (Katherine,)
# (Loaf,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Safe,)
# (accurate,)
# (The,)
# ()
# (file,)
# (Copy,)
# ()
# (For,)
# (EMPLOYEE'S,)
# (RECORDS,)
# ((See,)
# (Notice,)
# (to,)
# (FAST,)
# (Use,)
# (Employee,)
# (on,)
# (the,)
# (back,)
# (of,)
# (Copy,)
# (B.),)
# Updated 0d611bad-b2fe-4cf8-a634-cc5a1a79bf57_document-8_page-1.tsv with predictions.
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (Rev,)
# (file,)
# (806-87-1556,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Us,)
# (at,)
# (www.irs.gov/efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (23-0818096,)
# (143652,)
# ()
# (83,)
# (32981,)
# ()
# (78,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Butler,)
# (Walker,)
# (and,)
# (Huynh,)
# (LLC,)
# (161775,)
# (72,)
# (12375,)
# ()
# (84,)
# (20635,)
# (Ferguson,)
# (Knoll,)
# (Apt,)
# (904,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (116777,)
# ()
# (49,)
# (3386.55,)
# (Maryfort,)
# (ME,)
# (28982-8170,)
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (161775,)
# ()
# (72,)
# (116777,)
# ()
# (49,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (3,)
# (102,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (232,)
# ()
# (4733,)
# (Erin,)
# (Shields,)
# (13,)
# (Statutory,)
# (Retirement,)
# (ird-part,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# (37346,)
# (Brown,)
# (Crossroad,)
# ()
# (562,)
# (afurt,)
# (14,)
# (Other,)
# (12,)
# (WA,)
# (88489-2003,)
# ()
# (761,)
# (120,)
# (239,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (15,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (WY,)
# (377-99-655,)
# (72068,)
# ()
# (4414,)
# ()
# (98,)
# (172188.17,)
# (25920.93,)
# (Jennings,)
# (Drive,)
# (MT,)
# (756-36-466,)
# (67722,)
# ()
# (58,)
# (3859,)
# ()
# (79,)
# (166697,)
# (79,)
# (27406,)
# (26,)
# (Miller,)
# (Bridge,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Cut,)
# (here,)
# ()
# (Keep,)
# (lower,)
# (portion,)
# (for,)
# (your,)
# (records,)
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (If,)
# (you,)
# (are,)
# (required,)
# (806-87-1556,)
# (OMB,)
# (No,)
# (1545-0008,)
# (to,)
# (file,)
# ()
# (tax,)
# (return,)
# ()
# (negligence,)
# (penalty,)
# (or,)
# (other,)
# (sanction,)
# (may,)
# (be,)
# (imposed,)
# (on,)
# (you,)
# (if,)
# (this,)
# (income,)
# (is,)
# (taxable,)
# (and,)
# (you,)
# (fail,)
# (to,)
# (report,)
# (it,)
# ()
# (Employer,)
# (identification,)
# (number,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (23-0818096,)
# (143652,)
# (.83,)
# (32981,)
# ()
# (78,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Butler,)
# (Walker,)
# (and,)
# (Huynh,)
# (LLC,)
# (161775,)
# ()
# (72,)
# (12375,)
# ()
# (84,)
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (Medicare,)
# (tax,)
# (withheld,)
# (20635,)
# (Ferguson,)
# (Knoll,)
# (Apt,)
# (904,)
# (116777,)
# (49,)
# (3386.55,)
# (Maryfort,)
# (ME,)
# (28982-8170,)
# (Social,)
# (security,)
# (tips,)
# (Allocated,)
# (tips,)
# (161775,)
# ()
# (72,)
# (116777,)
# ()
# (49,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (8335987,)
# (LO,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (232,)
# ()
# (4733,)
# (Erin,)
# (Shields,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# (37346,)
# (Brown,)
# (Crossroad,)
# ()
# (562,)
# (Sarafurt,)
# (WA,)
# (88489-2003,)
# (14,)
# (Other,)
# ((see,)
# (enclosed,)
# (Notice,)
# (to,)
# (Employee,)
# ()
# (12c,)
# (761,)
# (12d,)
# (239,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (WY,)
# (377-99-655,)
# (72068,)
# ()
# (4414,)
# ()
# (98,)
# (172188,)
# ()
# (17,)
# (25920,)
# (93,)
# (Jennings,)
# (Drive,)
# (MT,)
# (756-36-46,)
# (57722,)
# ()
# (58,)
# (3859,)
# ()
# (79,)
# (166697,)
# (79,)
# (27406,)
# (26,)
# (Miller,)
# (Bridge,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Safe,)
# (accurate,)
# (inse,)
# ()
# (file,)
# (Copy,)
# ()
# (For,)
# (EMPLOYEE'S,)
# (RECORDS,)
# ((See,)
# (Notice,)
# (to,)
# (FAST,)
# (Use,)
# (Employee,)
# (on,)
# (the,)
# (back,)
# (of,)
# (Copy,)
# (B.),)
# Updated 16039dad-4c54-4562-9c30-eac57c31fa42_document-9_page-1.tsv with predictions.
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (750-14-5565,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Use,)
# ()
# (file,)
# (at,)
# (www.irs.gov/efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (66-0731868,)
# (80879,)
# (85,)
# (20557,)
# (83,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Castro,)
# (Mendez,)
# (and,)
# (Burke,)
# (Ltd,)
# (105041,)
# ()
# (31,)
# (8035,)
# ()
# (66,)
# (28518,)
# (Nelson,)
# (Valley,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (82905,)
# ()
# (76,)
# (2404.27,)
# (West,)
# (Tracy,)
# (WV,)
# (06181-3581,)
# (Social,)
# (security,)
# (tips,)
# (Allocated,)
# (tips,)
# (105041,)
# ()
# (31,)
# (82905,)
# ()
# (76,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (426267,)
# (283,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Brandon,)
# (Burns,)
# (170,)
# ()
# (8046,)
# (13,)
# (employee,)
# (Statutory,)
# (Retirement,)
# (sick,)
# (Third-party,)
# (12b,)
# (pay,)
# (949,)
# (Hector,)
# (Park,)
# ()
# (997,)
# (Peterston,)
# (IA,)
# (53758-7649,)
# (14,)
# (Other,)
# (12c,)
# ()
# ()
# (786,)
# (12d,)
# ()
# (|719,)
# (15,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (State,)
# (Employer's,)
# (state,)
# (ZIP,)
# (ID,)
# (code,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (AL,)
# (342-28-460,)
# (43732,)
# (07,)
# (2741,)
# (33,)
# (86806,)
# ()
# (86,)
# (15207,)
# ()
# (84,)
# (Hudson,)
# (Station,)
# (OR,)
# (043-88-962,)
# (40096,)
# ()
# (74,)
# (3813,)
# ()
# (18,)
# (60509,)
# ()
# (68,)
# (12425,)
# ()
# (38,)
# (Jacob,)
# (Mountain,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Cut,)
# (here,)
# (Keep,)
# (lower,)
# (portion,)
# (for,)
# (your,)
# (records,)
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# (If,)
# (you,)
# (are,)
# (750-14-5565,)
# (OMB,)
# (No,)
# (1545-0008,)
# (on,)
# (required,)
# (to,)
# (file,)
# ()
# (tax,)
# (return,)
# ()
# (negligence,)
# (penalty,)
# (or,)
# (other,)
# (sanction,)
# (may,)
# (be,)
# (imposed,)
# (you,)
# (if,)
# (this,)
# (income,)
# (is,)
# (taxable,)
# (and,)
# (you,)
# ()
# (fail,)
# (Federal,)
# (to,)
# (report,)
# ()
# (Employer,)
# (identification,)
# (number,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (income,)
# (it,)
# (tax,)
# (withheld,)
# (66-0731868,)
# (80879,)
# (85,)
# (20557,)
# (83,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Social,)
# (security,)
# (wages,)
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Castro,)
# (Mendez,)
# (and,)
# (Burke,)
# (Ltd,)
# (105041,)
# ()
# (31,)
# (8035,)
# ()
# (66,)
# (28518,)
# (Nelson,)
# (Valley,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (Medicare,)
# (tax,)
# (withheld,)
# (82905,)
# ()
# (76,)
# (2404,)
# ()
# (27,)
# (West,)
# (Tracy,)
# (WV,)
# (06181-3581,)
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (105041,)
# ()
# (31,)
# (82905,)
# ()
# (76,)
# ()
# (Control,)
# (number,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (426267,)
# (283,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Burns,)
# (170,)
# (8046,)
# (Brandon,)
# (13,)
# (employee,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# (949,)
# (Hector,)
# (Park,)
# (plan,)
# ()
# ()
# (997,)
# (Peterston,)
# (IA,)
# (53758-7649,)
# ...
# (FED,)
# (ID,)
# (number,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# (32-0145515,)
# ()
# (Social,)
# (security,)
# (tips,)
# (18,)
# (Allocated,)
# (tips,)
# (224790,)
# ()
# (15,)
# (167232.55,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (270,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (250,)
# ()
# (7467,)
# (14,)
# (Other,)
# (12b,)
# ()
# (587,)
# (120,)
# (12d,)
# ()
# (833,)
# (449,)
# (13,)
# (Stat,)
# (emp,)
# (Ret,)
# (Plan,)
# (3rd,)
# (party,)
# (sick,)
# (pay,)
# (elf,)
# (Employees,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# ()
# (Laurie,)
# (Sparks,)
# (32033,)
# (Williams,)
# (Islands,)
# (North,)
# (Vickiton,)
# (AR,)
# (29537-7006,)
# (15,)
# (State,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# ()
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (NC,)
# (91-21-380,)
# (118085.7,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (6627,)
# ()
# (84,)
# (228139,)
# ()
# (88,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (24225,)
# (44,)
# (Horton,)
# (Creek,)
# (Federal,)
# (Filing,)
# (Copy,)
# (Wage,)
# (and,)
# (Tax,)
# (W-2,)
# (Statement,)
# (2018,)
# (Copy,)
# ()
# (to,)
# (be,)
# (filed,)
# (with,)
# (employee's,)
# (Federal,)
# (Income,)
# (Tax,)
# (Return,)
# (OMB,)
# (No,)
# (1545-0008,)
# Updated f6745fcd-7e79-4b74-a457-1a110c21abad_document-9_page-1.tsv with predictions.
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# ()
# ()
# (file,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (610-45-5289,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Use,)
# (at,)
# (www.irs,)
# (gov.efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (31-1709120,)
# (183276.33,)
# (63293,)
# (77,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Wilson,)
# (Group,)
# (PLC,)
# (163872,)
# (.6,)
# (12536,)
# ()
# (25,)
# (3365,)
# (Cory,)
# (Loop,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (152346,)
# (.22,)
# (4418,)
# ()
# (04,)
# (North,)
# (Kevinhaven,)
# (NE,)
# (41043-8093,)
# ()
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (163872,)
# ()
# ()
# (152346.22,)
# ()
# (Control,)
# (number,)
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (3523929,)
# (274,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Buff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Katrina,)
# (Lopez,)
# (242,)
# ()
# (7112,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# (8959,)
# (Christopher,)
# (Row,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# ()
# (658,)
# (West,)
# (Stanley,)
# (RT,)
# (81407-4580,)
# (Other,)
# (12c,)
# (DD,)
# (418,)
# (12c,)
# ()
# (202,)
# (15,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (State,)
# (Employers,)
# (state,)
# (ID,)
# (number,)
# (In,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (TX,)
# (524-44-606,)
# (87817.7,)
# (4166,)
# ()
# (46,)
# (177938,)
# ()
# (12,)
# (32334,)
# (.47,)
# (Jacqueline,)
# (Shores,)
# (GA,)
# (597-40-950,)
# (89289,)
# (92,)
# (4839,)
# ()
# (76,)
# (194306,)
# ()
# (74,)
# (32872.53,)
# (Cynthia,)
# (Drive,)
# (Wage,)
# (and,)
# (Tax,)
# (2018,)
# (Department,)
# (of,)
# (the,)
# (Treasury,)
# (Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# Updated f6f8d955-263d-40e0-884b-12cc2d2c2766_document-8_page-1.tsv with predictions.
# (789-12-8667,)
# ()
# ()
# (file,)
# (62-7987120,)
# (64340.04,)
# (14341.59,)
# (modge,)
# (Group,)
# (PLC,)
# (53353.13,)
# (4001.51,)
# (278,)
# (Kristin,)
# (Common,)
# (Lake,)
# (william,)
# (07497-6950,)
# (59509.8,)
# (1720.1,)
# (53353.13,)
# (59509.0,)
# (0319522,)
# (160,)
# (Stephanie,)
# (Smith,)
# (160,)
# (DD,)
# (7750,)
# (17801,)
# (Melanie,)
# (Street,)
# (Suite,)
# (987,)
# (043,)
# (Taraburgh,)
# (MDM,)
# (68402-7091,)
# (AR,)
# (033-09-646,)
# (34124.55,)
# (1536.20,)
# (67008.10,)
# (8442.32,)
# (621-04-397,)
# (32359.87,)
# (1391.77,)
# (46955.06,)
# (0597.08,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (from,)
# (wa,)
# (789-12-8667,)
# (62-7587120,)
# (64340.84,)
# (14341.99,)
# (modge,)
# (Group,)
# (PLC,)
# (53353.13,)
# (4081.51,)
# (270,)
# (Kristin,)
# (Common,)
# (Lake,)
# (willian,)
# (CF,)
# (07497-6958,)
# (59509.8,)
# (1720.1,)
# (53353.13,)
# (59509.0,)
# (8319522,)
# (Stephanie,)
# (Smith,)
# (160,)
# (DD,)
# (7750,)
# (17881,)
# (Melanie,)
# (Street,)
# (Suite,)
# (987,)
# (843,)
# (Taraburgh,)
# (MDM,)
# (68402-7091,)
# (033-89-646,)
# (34124.55,)
# (1536.20,)
# (67008.10,)
# (0442.32,)
# (621-04-397,)
# (32359.87,)
# (1391.77,)
# (64955.06,)
# (8597.08,)
# (Wage,)
# (and,)
# (Tax,)
# (2019,)
# (form,)
# (wa,)
# (Stateim,)
# ()
# ()
# (file,)
# Updated f708389b-f475-4c7a-8a6f-7afdc590a2bb_document-9_page-1.tsv with predictions.
# (01449-2605,)
# ()
# (Employee's,)
# (social,)
# (security,)
# (number,)
# (Safe,)
# (Accurate,)
# (Re,)
# (file,)
# (at,)
# (Visit,)
# (the,)
# (IRS,)
# (Website,)
# (700-94-7710,)
# (OMB,)
# (No,)
# (1545-0008,)
# (FAST,)
# (Use,)
# (www.irs.gov/efile,)
# ()
# (Employer,)
# (identification,)
# (number,)
# ((EIN,)
# (Wages,)
# (tips,)
# (other,)
# (compensation,)
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (42-6864147,)
# (135716,)
# (39,)
# (36344,)
# ()
# (65,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (Cooper,)
# (Rosales,)
# (and,)
# (Hernandez,)
# (Inc,)
# (155510,)
# (.73,)
# (11896,)
# (.57,)
# (915,)
# (Shepard,)
# (Village,)
# (Apt,)
# (701,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (146671,)
# ()
# (64,)
# (4253,)
# ()
# (48,)
# (North,)
# (John,)
# (NH,)
# (55441-0437,)
# ()
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (155510,)
# ()
# (73,)
# (146671,)
# ()
# (64,)
# ()
# (Control,)
# (number,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (8345532,)
# (116,)
# ()
# (Employee's,)
# (first,)
# (name,)
# (and,)
# (initial,)
# (Last,)
# (name,)
# (Suff,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (Christopher,)
# (Bradshaw,)
# (208,)
# (BB,)
# (8197,)
# (13,)
# (Statutory,)
# (Retirement,)
# (Third-party,)
# (12b,)
# (7745,)
# (Shelly,)
# (Stravenue,)
# (employee,)
# (plan,)
# (sick,)
# (pay,)
# ()
# (AA,)
# (384,)
# (South,)
# (Devin,)
# (NY,)
# (14,)
# (Other,)
# (HH,)
# (615,)
# (12d,)
# ()
# (883,)
# (15,)
# ()
# (Employee's,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (State,)
# (Employer's,)
# (state,)
# (ID,)
# (number,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (TN,)
# (608-97-314,)
# (64536,)
# (17,)
# (6663.78,)
# (147295,)
# ()
# (44,)
# (23296.57,)
# (Fisher,)
# (Plain,)
# (WV,)
# (752-19-975,)
# (68955,)
# ()
# (72,)
# (7809,)
# (11,)
# (124178,)
# (.0,)
# (25189,)
# ()
# (74,)
# (Timothy,)
# (Crest,)
# (Wage,)
# (and,)
# (Tax,)
# (2018,)
# (Department,)
# (of,)
# (the,)
# (Treasury--Internal,)
# (Revenue,)
# (Service,)
# (Form,)
# (W-2,)
# (Statement,)
# (Copy,)
# (B--To,)
# (Be,)
# (Filed,)
# (with,)
# (Employee's,)
# (FEDERAL,)
# (Tax,)
# (Return,)
# (This,)
# (information,)
# (is,)
# (being,)
# (furnished,)
# (to,)
# (the,)
# (Internal,)
# (Revenue,)
# (Service,)
# Updated f81ed02e-f320-4082-aee7-f6c52ec68fa5_document-3_page-1.tsv with predictions.
# (238003,)
# (Wages,)
# (tips,)
# (other,)
# (comp,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (226026,)
# ()
# (52,)
# (78719,)
# (87,)
# ()
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (238003,)
# ()
# (48,)
# (18207,)
# (.27,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (171560,)
# ()
# (91,)
# (4975.27,)
# ()
# (Control,)
# (number,)
# (Dept,)
# (Corp.,)
# (Employer,)
# (use,)
# (only,)
# (9897129,)
# (150,)
# ()
# (36,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Clark-Smith,)
# (Group,)
# (31046,)
# (Hartman,)
# (Cape,)
# (New,)
# (Emma,)
# (NV,)
# (82314-6154,)
# (Batch,)
# (#02021,)
# ()
# (Employer's,)
# (FED,)
# (ID,)
# (number,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# (33-6879304,)
# ()
# (Social,)
# ()
# ()
# (security,)
# (tips,)
# (Allocated,)
# (tips,)
# ()
# (48,)
# (171560,)
# ()
# (91,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (267,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (280,)
# ()
# (7709,)
# (14,)
# (Other,)
# (12b,)
# ()
# (531,)
# (12c,)
# ()
# (557,)
# (12d,)
# ()
# (424,)
# (13,)
# (Stat,)
# (emp,)
# (Ret,)
# (Plan,)
# (3rd,)
# (party,)
# (sick,)
# (pay,)
# (elf,)
# (Employees,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Brooke,)
# (Logan,)
# (88763,)
# (Steele,)
# (Manor,)
# (North,)
# (Toniton,)
# (ND,)
# (36783-5234,)
# (15,)
# (State,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (NM,)
# (19-43-761,)
# (117291,)
# ()
# (76,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (7333,)
# (57,)
# (170817,)
# ()
# (48,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (26560,)
# ()
# (91,)
# (Scott,)
# (Club,)
# (Federal,)
# (Filing,)
# (Copy,)
# (Wage,)
# (and,)
# (Tax,)
# (W-2,)
# (Statement,)
# (2018,)
# (Copy,)
# ()
# (to,)
# (be,)
# (filed,)
# (with,)
# (employee's,)
# (Federal,)
# (Income,)
# (Tax,)
# (Return,)
# (OMB,)
# (No,)
# (1545-0008,)
# Updated fcdd2c05-c5ae-41cb-a262-4dbbd53f139b_document-9_page-1.tsv with predictions.
# (12a,)
# ()
# (Federal,)
# (income,)
# (7266,)
# (tax,)
# (withheld,)
# (.74,)
# (Wages,)
# (53601.87,)
# (tips,)
# (other,)
# (comp,)
# ()
# (Social,)
# (security,)
# (3872,)
# (tax,)
# (withheld,)
# ()
# (71,)
# ()
# (Social,)
# (50623,)
# (security,)
# (67,)
# (wages,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (1736.78,)
# ()
# (Medicare,)
# (59888,)
# (wages,)
# ()
# (83,)
# (and,)
# (tips,)
# (Employer,)
# (use,)
# (36,)
# (only,)
# (Dept,)
# (150,)
# (Corp,)
# ()
# ()
# (Control,)
# (number,)
# (1231167,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (LLC,)
# (Serrano-Brown,)
# (ZIP,)
# (code,)
# (20433,)
# (Stone,)
# (Ports,)
# (54827-9849,)
# (Port,)
# (Matthew,)
# (ID,)
# (#02021,)
# (Batch,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# ()
# (Employer's,)
# (FED,)
# (ID,)
# (number,)
# (57-9559082,)
# (Allocated,)
# (tips,)
# (59888,)
# (.83,)
# (Social,)
# (50623,)
# (security,)
# (67,)
# (tips,)
# (10,)
# (Dependent,)
# (care,)
# (180,)
# (benefits,)
# (19,)
# (Verification,)
# (Code,)
# (12,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# ()
# (11,)
# (Nonqualified,)
# ()
# (6264,)
# (283,)
# (plans,)
# (12b,)
# ()
# ()
# (173,)
# (12c,)
# (92,)
# (14,)
# (Other,)
# (12d,)
# (682,)
# (13,)
# (Stat,)
# (emp,)
# (Ret,)
# (Plan,)
# (3rd,)
# (party,)
# (sick,)
# (pay,)
# (elf,)
# (Employees,)
# (name,)
# (address,)
# (Callahan,)
# (and,)
# (ZIP,)
# (code,)
# (Mariah,)
# (476,)
# (Reynolds,)
# (Square,)
# (Suite,)
# (181,)
# (East,)
# (Amyshire,)
# (WA,)
# (48586-2327,)
# (State,)
# (wages,)
# (tips,)
# (27948,)
# (etc,)
# ()
# (41,)
# (15,)
# (State,)
# (AR,)
# (30-10-140,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (42339.58,)
# (etc,)
# (17,)
# (State,)
# (3034,)
# (income,)
# (41,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (Bradley,)
# (Mews,)
# (19,)
# (Local,)
# (10233,)
# (income,)
# (49,)
# (tax,)
# (Copy,)
# (Filing,)
# (Federal,)
# (Wage,)
# (and,)
# (Tax,)
# (2018,)
# (Statement,)
# (W-2,)
# (OMB,)
# (No,)
# (1545-0008,)
# (Copy,)
# ()
# (to,)
# (be,)
# (filed,)
# (with,)
# (employee's,)
# (Federal,)
# (Income,)
# (Tax,)
# (Return,)
# Updated fdfa8d6d-6879-4cf1-851f-cccae76e294a_document-10_page-1.tsv with predictions.
# (Wages,)
# (tips,)
# (other,)
# (comp,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (134662,)
# ()
# (84,)
# (23337,)
# (.6,)
# ()
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (106558,)
# (.32,)
# (8151,)
# ()
# (71,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# ()
# (Medicare,)
# (tax,)
# (withheld,)
# (103685.73,)
# (3006,)
# ()
# (89,)
# ()
# (Control,)
# (number,)
# (Dept,)
# (150,)
# (Corp.,)
# (Employer,)
# (use,)
# (only,)
# (2294434,)
# ()
# (36,)
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Lewis-Jones,)
# (Ltd,)
# (51528,)
# (Stacey,)
# (Run,)
# (Apt,)
# (819,)
# (West,)
# (Glenn,)
# (IA,)
# (21762-9449,)
# (Batch,)
# (#02021,)
# ()
# (Employer's,)
# (FED,)
# (ID,)
# (number,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# (61-0262542,)
# ()
# (Social,)
# (security,)
# (tips,)
# ()
# (Allocated,)
# (tips,)
# (106558,)
# (.32,)
# (103685,)
# (73,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (124,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (165,)
# (14,)
# (Other,)
# ()
# ()
# (4847,)
# (12b,)
# (|738,)
# (12c,)
# ()
# (218,)
# (12d,)
# ()
# (401,)
# (13,)
# (Stat,)
# (emp,)
# (Ret,)
# (Plan,)
# (3rd,)
# (party,)
# (sick,)
# (pay,)
# (elf,)
# (Employees,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (Cody,)
# (Thomas,)
# (13796,)
# (Jackson,)
# (Port,)
# (Suite,)
# (809,)
# (Dannyview,)
# (FL,)
# (45751-9574,)
# (15,)
# (State,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (MS,)
# (63-79-397,)
# (70317,)
# ()
# (97,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (3933.37,)
# (122431,)
# (23,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (19502,)
# ()
# (52,)
# (Rodriguez,)
# (Summit,)
# (Federal,)
# (Filing,)
# (Copy,)
# (Wage,)
# (and,)
# (Tax,)
# (W-2,)
# (Statement,)
# (2018,)
# (Copy,)
# ()
# (to,)
# (be,)
# (filed,)
# (with,)
# (employee's,)
# (Federal,)
# (Income,)
# (Tax,)
# (Return,)
# (OMB,)
# (No,)
# (1545-0008,)
# Updated fdfa8d6d-6879-4cf1-851f-cccae76e294a_document-4_page-1.tsv with predictions.
# (Employer's,)
# (200403.29,)
# (202261,)
# (Wages,)
# (tips,)
# (other,)
# (comp,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (21:867,)
# ()
# (95,)
# ()
# (Social,)
# (security,)
# (wages,)
# (55957.51,)
# (20,)
# ()
# ()
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (15330,)
# (85,)
# ()
# (.68,)
# (Medicare,)
# (tax,)
# (withheld,)
# ()
# (Control,)
# (number,)
# (5865.59,)
# (3192339,)
# (Dept,)
# (Corp,)
# (150,)
# ()
# (Employer,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# ()
# (use,)
# (36,)
# (only,)
# (Morales-Walters,)
# (and,)
# (Sons,)
# (6362,)
# (Cannon,)
# (Shoal,)
# (Apt,)
# (825,)
# (New,)
# (Bridget,)
# (IL,)
# (15571-3500,)
# (Batch,)
# (#02021,)
# ()
# (Employer's,)
# (FED,)
# (ID,)
# (number,)
# (04-4331208,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# ()
# (Social,)
# (security,)
# (tips,)
# (200403.29,)
# ()
# (Allocated,)
# (tips,)
# (Verification,)
# (Code,)
# (202261,)
# (68,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (11,)
# (Nonqualified,)
# (plans,)
# (118,)
# (206,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (14,)
# (Other,)
# (2855,)
# (12b,)
# (516,)
# (12c,)
# (697,)
# (12d,)
# (205,)
# (eff,)
# (Employees,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (13,)
# (Stat,)
# (emp,)
# (Ret,)
# (Plan,)
# (3rd,)
# (party,)
# (sick,)
# (pay,)
# (Joseph,)
# (Strickland,)
# (3623,)
# (Arthur,)
# (Mews,)
# (Apt,)
# (410,)
# (New,)
# (Staceyville,)
# (NV,)
# (15,)
# (State,)
# (02814-0091,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# (State,)
# (wages,)
# (tips,)
# (etc,)
# (RI,)
# (54-28-049,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (1:0986,)
# (.9,)
# (5550.54,)
# (18,)
# (Local,)
# (wages,)
# (tips,)
# (etc,)
# (19,)
# (Local,)
# (income,)
# (tax,)
# (17:350.39,)
# (40017,)
# (79,)
# (Locality,)
# (name,)
# (Anthony,)
# (Mews,)
# (Federal,)
# (Filing,)
# (W-2,)
# (Wage,)
# (and,)
# (Tax,)
# (Copy,)
# (Statement,)
# (Copy,)
# ()
# (to,)
# (be,)
# (filed,)
# (with,)
# (employee's,)
# (Federal,)
# (Income,)
# (Tax,)
# (Return,)
# (2018,)
# (OMB,)
# (No,)
# (1545-0008,)
# Updated fdfa8d6d-6879-4cf1-851f-cccae76e294a_document-8_page-1.tsv with predictions.
# (Wages,)
# (tips,)
# (other,)
# (comp,)
# ()
# (Federal,)
# (income,)
# (tax,)
# (withheld,)
# (194537.25,)
# (65004,)
# ()
# ()
# ()
# (Social,)
# (security,)
# (wages,)
# ()
# (Social,)
# (security,)
# (tax,)
# (withheld,)
# (174117,)
# (83,)
# (13320,)
# ()
# (01,)
# ()
# (Medicare,)
# (wages,)
# (and,)
# (tips,)
# (Medicare,)
# (tax,)
# (withheld,)
# (136727,)
# (.71,)
# (3965.1,)
# ()
# (Control,)
# (number,)
# (Dept,)
# (150,)
# (Corp.,)
# (Employer,)
# (use,)
# (36,)
# (only,)
# (912215,)
# ()
# ()
# (Employer's,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Porter,)
# (Mcmahon,)
# (and,)
# (Campos,)
# (Group,)
# (82304,)
# (Haney,)
# (Court,)
# (Knappfort,)
# (NH,)
# (53016-9992,)
# (Batch,)
# (#02021,)
# ()
# (Employer's,)
# (FED,)
# (ID,)
# (number,)
# ()
# (Employee's,)
# (SSA,)
# (number,)
# (35-3379636,)
# ()
# ()
# (Social,)
# (security,)
# (tips,)
# (18,)
# (Allocated,)
# (tips,)
# (174117,)
# ()
# (83,)
# (136727,)
# ()
# (71,)
# ()
# (Verification,)
# (Code,)
# (10,)
# (Dependent,)
# (care,)
# (benefits,)
# (230,)
# (11,)
# (Nonqualified,)
# (plans,)
# (12a,)
# (See,)
# (instructions,)
# (for,)
# (box,)
# (12,)
# (187,)
# ()
# (3109,)
# (14,)
# (Mother,)
# ()
# (872,)
# (126,)
# (it,)
# (99s,)
# (Star,)
# (anne,)
# (FRO,)
# (Plan,)
# (3rd,)
# (party,)
# (sick,)
# (pay,)
# (elf,)
# (Employees,)
# (name,)
# (address,)
# (and,)
# (ZIP,)
# (code,)
# (Troy,)
# (Jennings,)
# (7412,)
# (Williams,)
# (View,)
# (Apt.215,)
# (Conradberg,)
# (AL,)
# (25880-3210,)
# ()
# (or,)
# (State,)
# (Employers,)
# (state,)
# (ID,)
# (no,)
# (16,)
# (State,)
# (wages,)
# ()
# (tips,)
# (etc,)
# (CA,)
# (29-02-307,)
# (17,)
# (State,)
# (income,)
# (tax,)
# (18,)
# (Local,)
# (wages,)
# (tipszero,)
# (6537,)
# (.6,)
# (20134,)
# (197Local,)
# (income,)
# (tax,)
# (20,)
# (Locality,)
# (name,)
# (196421,)
# (15,)
# (Brook,)
# (Federal,)
# (.Filing,)
# (Copy,)
# (Wage,)
# (and,)
# (W-2,)
# (Statement,)
# (2018,)
# (Copy,)
# ()
# (to,)
# (be,)
# (filed,)
# (with,)
# (employee's,)
# (Federal,)
# (income,)
# (Tax,)
# (Return,)
# (OMB,)
# (No,)
# (1545-0008,)
# Updated fdfa8d6d-6879-4cf1-851f-cccae76e294a_document-9_page-1.tsv with predictions.
